# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('store-data.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
# df.describe()
df.shape
# Out:
# (10064, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code       object
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity         float64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10064 entries, 0 to 10063
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         10064 non-null  int64
#  1   Order ID       10064 non-null  object
#  2   Order Date     10064 non-null  object
#  3   Ship Date      9963 non-null   object
#  4   Ship Mode      9763 non-null   object
#  5   Customer ID    10064 non-null  object
#  6   Customer Name  9713 non-null   object
#  7   Segment        10064 non-null  object
#  8   Country        10064 non-null  object
#  9   City           10064 non-null  object
#  10  State          10064 non-null  object
#  11  Postal Code    9864 non-null   object
#  12  Region         10064 non-null  object
#  13  Product ID     10064 non-null  object
#  14  Category       10064 non-null  object
#  15  Sub-Category   10064 non-null  object
#  16  Product Name   10064 non-null  object
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     16
# float64     4
# int64       1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date        101
# Ship Mode        301
# Customer ID        0
# Customer Name    351
# Segment            0
# Country            0
# City               0
# State              0
# Postal Code      200
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales            201
# Quantity         199
# Discount           0
# Profit             0
# dtype: int64

# %%
df.isna().sum()[df.isna().sum()<1]
# Out:
# Row ID          0
# Order ID        0
# Order Date      0
# Customer ID     0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Product ID      0
# Category        0
# Sub-Category    0
# Product Name    0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.isna().sum()[df.isna().sum()>=1]
# Out:
# Ship Date        101
# Ship Mode        301
# Customer Name    351
# Postal Code      200
# Sales            201
# Quantity         199
# dtype: int64

# %%
df.nunique() #ignore NaN.
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1495
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     810
# Segment             6
# Country             1
# City              633
# State              86
# Postal Code       705
# Region              4
# Product ID       1862
# Category            6
# Sub-Category       17
# Product Name     1850
# Sales            5738
# Quantity           15
# Discount           13
# Profit           7287
# dtype: int64

# %%
df.nunique(dropna=True)
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1495
# Ship Date        1335
# Ship Mode           5
# Customer ID       793
# Customer Name     811
# Segment             6
# Country             1
# City              633
# State              86
# Postal Code       706
# Region              4
# Product ID       1862
# Category            6
# Sub-Category       17
# Product Name     1850
# Sales            5739
# Quantity           16
# Discount           13
# Profit           7287
# dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# Row ID      4994.397059
# Sales       1950.322096
# Quantity       3.780233
# Discount       0.157501
# Profit        28.571309
# dtype: float64

# %%
df.describe()
# Out:
#              Row ID         Sales     Quantity      Discount        Profit
# count  10064.000000  9.863000e+03  9865.000000  10064.000000  10064.000000
# mean    4994.397059  1.950322e+03     3.780233      0.157501     28.571309
# std     2885.848580  4.410673e+04     2.240134      0.210586    233.509461
# min        1.000000  4.440000e-01    -5.000000      0.000000  -6599.978000
# 25%     2496.750000  1.729000e+01     2.000000      0.000000      1.724800
# 50%     4989.500000  5.450000e+01     3.000000      0.200000      8.643600
# 75%     7494.250000  2.107600e+02     5.000000      0.200000     29.331600
# max     9994.000000  1.131924e+06    14.000000      1.500000   8399.976000

# %%
df.describe(include='object')
# Out:
#               Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# count            10064      10064        9963            9763       10064
# unique            5009       1495        1334               4         793
# top     CA-2017-100111   9/5/2016  12/16/2015  Standard Class    WB-21850
# freq                14         39          35            5822          38
#
#         Customer Name   Segment        Country           City       State  \
# count            9713     10064          10064          10064       10064
# unique            810         6              1            633          86
# top     William Brown  Consumer  United States  New York City  California
# freq               36      5163          10064            896        1967
#
#        Postal Code Region       Product ID         Category Sub-Category  \
# count         9864  10064            10064            10064        10064
# unique         705      4             1862                6           17
# ...

# %%
df.describe(include='all')
# Out:
#               Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# count   10064.000000           10064      10064        9963            9763
# unique           NaN            5009       1495        1334               4
# top              NaN  CA-2017-100111   9/5/2016  12/16/2015  Standard Class
# freq             NaN              14         39          35            5822
# mean     4994.397059             NaN        NaN         NaN             NaN
# std      2885.848580             NaN        NaN         NaN             NaN
# min         1.000000             NaN        NaN         NaN             NaN
# 25%      2496.750000             NaN        NaN         NaN             NaN
# 50%      4989.500000             NaN        NaN         NaN             NaN
# 75%      7494.250000             NaN        NaN         NaN             NaN
# max      9994.000000             NaN        NaN         NaN             NaN
#
# ...

# %%
# df['Ship Mode'].value_counts()
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    5942
# Furniture          2095
# Technology         1826
# office supplies     123
# furniture            42
# technology           36
# Name: count, dtype: int64

# %%
df['Category'].value_counts(dropna=True)
# Out:
# Category
# Office Supplies    5942
# Furniture          2095
# Technology         1826
# office supplies     123
# furniture            42
# technology           36
# Name: count, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1532
# Paper          1378
# Furnishings     966
# Phones          899
# Storage         853
# Art             803
# Accessories     780
# Chairs          622
# Appliances      469
# Labels          366
# Tables          321
# Envelopes       254
# Bookcases       228
# Fasteners       220
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df['Sales'].value_counts().sort_values()
# Out:
# Sales
# 270.000     1
# 8.896       1
# 4.064       1
# 599.165     1
# 84.550      1
#            ..
# 10.368     36
# 25.920     36
# 19.440     39
# 15.552     40
# 12.960     55
# Name: count, Length: 5738, dtype: int64

# %%
df['Sales'].value_counts(normalize=True).sort_values()
# Out:
# Sales
# 270.000    0.000101
# 8.896      0.000101
# 4.064      0.000101
# 599.165    0.000101
# 84.550     0.000101
#              ...
# 10.368     0.003650
# 25.920     0.003650
# 19.440     0.003954
# 15.552     0.004056
# 12.960     0.005576
# Name: proportion, Length: 5738, dtype: float64

# %%
df.groupby('Category')['Sales'].sum()
df.groupby('Category')['Profit'].sum()
# Out:
# Category
# Furniture           18189.1929
# Office Supplies    119693.6989
# Technology         143463.9587
# furniture              56.8583
# office supplies      3331.9154
# technology           2806.0269
# Name: Profit, dtype: float64

# %%
df[df.Discount>100].Discount.shape
# Out:
# (0,)

# %%
df[df.Quantity<0].Quantity.shape
# Out:
# (10,)

# %%
df[ df["Ship Date"] < df["Order Date"] ]["Ship Date"].shape
# Out:
# (8,)

# %%
# sns.countplot(data=df,x='Category',color='orange')
# plt.xticks(rotation=45)
# plt.show()
sns.catplot(data=df,y='Category',kind='count',color='orange',aspect=2)
plt.show()

# %%
sns.catplot(data=df,y='Ship Mode',kind='count',color='orange',aspect=2)
plt.show()

# %%
sns.catplot(data=df,y='Segment',kind='count',color='orange',aspect=2)
plt.show()

# %%
sns.catplot(data=df,y='Region',kind='count',color='orange',aspect=2)
plt.show()

# %%
sns.catplot(data=df,y='Sub-Category',kind='count',color='orange',aspect=2)
plt.show()

# %%
fig,ax = plt.subplots()
sns.histplot(data=df,x='Quantity')
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>
